# %%
# import basic libraries for data manipulation

import pandas as pd
import numpy as np

# import libraries for visualization

import seaborn as sns
from matplotlib.pyplot import plot, figure

# %matplotlib inline

# %%
# reading train and test csv files and storing as dataframes

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
# input data have totall 11 columns, of which 
# "PassengerId" is index for each passenger, whhich will not derive any useful information. it can be dropped from input
# "Name" can be removed to protect identity
# "Ticket" are bunch of random values, hence this to can be dropped
# "Cabin" also have random values and most missing values, this can be dropped 

train = train.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)

# Since feature "Embarked" has only 2 missing value, lets impute them with most frequent value aka "mode"

train['Embarked'] = train['Embarked'].fillna(train["Embarked"].mode()[0])

# %%
# Convert categorical values to numeric

train['Embarked'] = train['Embarked'].map({'S':0, 'C':1, 'Q':2})
train['Sex'] = train['Sex'].map({'male': 0, 'female': 1})

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    int64
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB

# %%
figure(figsize = (4,5))
sns.pairplot(train, hue='Survived')
# Out:
# /home/saikrishna/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/saikrishna/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)
# /home/saikrishna/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %%
figure(figsize=(12,10))
sns.heatmap(train.corr(), annot=True)

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors = 10, copy= True)

new_train = imputer.fit_transform(train)

# %%
new_train = pd.DataFrame(new_train, columns=train.columns)
new_train.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       0.0     3.0  0.0  22.0    1.0    0.0   7.2500       0.0
# 1       1.0     1.0  1.0  38.0    1.0    0.0  71.2833       1.0
# 2       1.0     3.0  1.0  26.0    0.0    0.0   7.9250       0.0
# 3       1.0     1.0  1.0  35.0    1.0    0.0  53.1000       0.0
# 4       0.0     3.0  0.0  35.0    0.0    0.0   8.0500       0.0

# %%
new_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    float64
#  1   Pclass    891 non-null    float64
#  2   Sex       891 non-null    float64
#  3   Age       891 non-null    float64
#  4   SibSp     891 non-null    float64
#  5   Parch     891 non-null    float64
#  6   Fare      891 non-null    float64
#  7   Embarked  891 non-null    float64
# dtypes: float64(8)
# memory usage: 55.8 KB

# %%
# "Survived" is our actual target class which denotes whether that particular person survived in that disaster or not
# "0" denotes "deseased" and "1" means "Survived"

y = new_train['Survived']
X = new_train.drop(['Survived'], axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state =1, train_size= 0.75, test_size= 0.25)

# %%
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from lightgbm import LGBMClassifier

from sklearn.metrics import accuracy_score as accuracy

xgb = XGBClassifier()
dtc = DecisionTreeClassifier()
rfc = RandomForestClassifier()
lgb = LGBMClassifier()

models = [xgb, dtc, rfc, lgb]

# %%
for model in models:
    model.fit(X_train, y_train)
    predictions = model.predict(X_test)
    model_name = repr(model)
    print(f"{model_name[:str.find(model_name, '(')]} : {accuracy(y_test, predictions)}")
# Out:
# XGBClassifier : 0.7802690582959642
# DecisionTreeClassifier : 0.757847533632287
# RandomForestClassifier : 0.7847533632286996
# LGBMClassifier : 0.7847533632286996
